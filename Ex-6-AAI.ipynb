# %%
import nltk
nltk.download('punkt')
nltk.download('wordnet')
nltk.download('omw-1.4')
nltk.download('averaged_perceptron_tagger')

from nltk.tokenize import word_tokenize
from nltk.corpus import wordnet

# Give your input sentence directly here
sentence = "Live as if you were to die tomorrow."

# Tokenize the sentence into words
words = word_tokenize(sentence)

# Identify the parts of speech for each word
pos_tags = nltk.pos_tag(words)

# Identify synonyms and antonyms for each word
synonyms = []
antonyms = []

for word in words:
    for syn in wordnet.synsets(word):
        for lemma in syn.lemmas():
            synonyms.append(lemma.name())
            if lemma.antonyms():
                antonyms.append(lemma.antonyms()[0].name())

# Print the synonyms and antonyms
print("Sentence:", sentence)
print("Synonyms:", set(synonyms))
print("Antonyms:", set(antonyms))
# Out:
# Sentence: Live as if you were to die tomorrow.
# Synonyms: {'constitute', 'survive', 'fail', 'arsenic', 'springy', 'be', 'expire', 'become_flat', 'bouncy', 'represent', 'buy_the_farm', 'conk_out', 'comprise', 'dice', 'antiophthalmic_factor', 'atomic_number_33', 'A', 'endure', 'group_A', 'give_way', 'snuff_it', 'perish', 'inhabit', 'axerophthol', 'break', 'last', 'go', 'a', 'As', 'as', 'every_bit', 'kick_the_bucket', 'go_bad', 'decease', 'type_A', 'experience', 'live_on', 'give-up_the_ghost', 'pall', 'croak', 'amp', 'subsist', 'ampere', 'tomorrow', 'exit', 'angstrom_unit', 'adenine', 'conk', 'unrecorded', 'resilient', 'equal', 'AS', 'pass_away', 'follow', 'embody', 'give_out', 'hold_out', 'know', 'die_out', 'deoxyadenosine_monophosphate', 'equally', 'exist', 'dwell', 'alive', 'live', 'American_Samoa', 'Eastern_Samoa', 'break_down', 'angstrom', 'lively', 'cost', 'hold_up', 'hot', 'vitamin_A', 'personify', 'populate', "cash_in_one's_chips", 'pop_off', 'drop_dead', 'pass', 'choke', 'make_up', 'die'}
# Antonyms: {'recorded', 'be_born', 'dead', 'differ'}
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\admin\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\admin\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\admin\AppData\Roaming\nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\admin\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
